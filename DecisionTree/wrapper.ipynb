# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix,accuracy_score,f1_score
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV
from sklearn.feature_selection import SelectKBest, f_classif,chi2
import numpy as np
from tqdm import tqdm

# %%
class FeatureSelector:
    """
    Feature selection using Forward Selection and Backward Elimination
    Supports both Classification and Regression
    """
    
    def __init__(self, estimator=None, scoring='accuracy', task='classification'):
        """
        Parameters:
        -----------
        estimator : sklearn estimator (default: DecisionTreeClassifier)
        scoring : str, 'accuracy', 'f1', 'roc_auc' for classification; 'r2', 'rmse' for regression
        task : str, 'classification' or 'regression'
        """
        self.estimator = estimator if estimator else DecisionTreeClassifier()
        self.scoring = scoring
        self.task = task
        
    def _evaluate_features(self, X_train, y_train, X_val, y_val, features):
        """Evaluate a subset of features"""
        if len(features) == 0:
            return -np.inf
        
        X_train_subset = X_train[:, features]
        X_val_subset = X_val[:, features]
        
        # Train model
        self.estimator.fit(X_train_subset, y_train)
        
        # Predict
        if self.task == 'classification':
            y_pred = self.estimator.predict(X_val_subset)
            
            # Calculate score based on metric
            if self.scoring == 'accuracy':
                score = accuracy_score(y_val, y_pred)
            elif self.scoring == 'f1':
                score = f1_score(y_val, y_pred, average='weighted')
            elif self.scoring == 'roc_auc':
                # Need probability predictions for ROC AUC
                if hasattr(self.estimator, 'predict_proba'):
                    y_pred_proba = self.estimator.predict_proba(X_val_subset)
                    if y_pred_proba.shape[1] == 2:
                        score = roc_auc_score(y_val, y_pred_proba[:, 1])
                    else:
                        score = roc_auc_score(y_val, y_pred_proba, multi_class='ovr', average='weighted')
                else:
                    score = accuracy_score(y_val, y_pred)  # Fallback
        else:  # regression
            y_pred = self.estimator.predict(X_val_subset)
            from sklearn.metrics import r2_score, mean_squared_error
            if self.scoring == 'r2':
                score = r2_score(y_val, y_pred)
            else:  # rmse
                score = -np.sqrt(mean_squared_error(y_val, y_pred))
        
        return score
    
    def forward_selection(self, X_train, y_train, X_val, y_val, 
                         max_features=30, min_improvement=0.0001, verbose=True):
        """
        Forward Selection: Start with no features, add one at a time
        
        Parameters:
        -----------
        X_train : array-like, training features
        y_train : array-like, training target
        X_val : array-like, validation features
        y_val : array-like, validation target
        max_features : int, maximum features to select
        min_improvement : float, minimum improvement to continue
        verbose : bool, print progress
        
        Returns:
        --------
        dict with selected features and scores
        """
        n_features = X_train.shape[1]
        selected_features = []
        remaining_features = list(range(n_features))
        scores_history = []
        
        best_score = -np.inf
        
        print("=" * 70)
        print("FORWARD SELECTION")
        print("=" * 70)
        print(f"Total available features: {n_features}")
        print(f"Maximum features to select: {max_features}")
        print(f"Scoring metric: {self.scoring}")
        print("=" * 70)
        
        for iteration in range(min(max_features, n_features)):
            best_feature = None
            best_iter_score = -np.inf
            
            if verbose:
                print(f"\n--- Iteration {iteration + 1} ---")
                print(f"Evaluating {len(remaining_features)} remaining features...")
            
            # Try adding each remaining feature
            for idx, feature in enumerate(remaining_features):
                candidate_features = selected_features + [feature]
                score = self._evaluate_features(X_train, y_train, X_val, y_val, candidate_features)
                
                if score > best_iter_score:
                    best_iter_score = score
                    best_feature = feature
            
            # Check for improvement
            improvement = best_iter_score - best_score
            
            if improvement < min_improvement and len(selected_features) > 0:
                if verbose:
                    print(f"\n✓ Stopping: Improvement {improvement:.6f} < {min_improvement}")
                break
            
            # Add best feature
            selected_features.append(best_feature)
            remaining_features.remove(best_feature)
            best_score = best_iter_score
            scores_history.append({
                'n_features': len(selected_features),
                'feature_added': best_feature,
                'score': best_score
            })
            
            if verbose:
                print(f"✓ Added feature {best_feature} | "
                      f"{self.scoring.upper()}: {best_score:.6f} | "
                      f"Improvement: +{improvement:.6f} | "
                      f"Total features: {len(selected_features)}")
        
        print("\n" + "=" * 70)
        print(f"FORWARD SELECTION COMPLETE")
        print(f"Selected {len(selected_features)} features")
        print(f"Final {self.scoring}: {best_score:.6f}")
        print("=" * 70)
        
        return {
            'selected_features': selected_features,
            'scores_history': scores_history,
            'final_score': best_score,
            'n_features': len(selected_features)
        }
    
    def backward_elimination(self, X_train, y_train, X_val, y_val,
                           min_features=5, min_improvement=0.0001, verbose=True):
        """
        Backward Elimination: Start with all features, remove one at a time
        
        Parameters:
        -----------
        X_train : array-like, training features
        y_train : array-like, training target
        X_val : array-like, validation features
        y_val : array-like, validation target
        min_features : int, minimum features to keep
        min_improvement : float, minimum improvement to continue
        verbose : bool, print progress
        
        Returns:
        --------
        dict with selected features and scores
        """
        n_features = X_train.shape[1]
        selected_features = list(range(n_features))
        scores_history = []
        
        # Initial score with all features
        best_score = self._evaluate_features(X_train, y_train, X_val, y_val, selected_features)
        
        print("\n" + "=" * 70)
        print("BACKWARD ELIMINATION")
        print("=" * 70)
        print(f"Starting with all {n_features} features")
        print(f"Minimum features to keep: {min_features}")
        print(f"Initial {self.scoring}: {best_score:.6f}")
        print("=" * 70)
        
        iteration = 0
        while len(selected_features) > min_features:
            iteration += 1
            worst_feature = None
            best_iter_score = -np.inf
            
            if verbose:
                print(f"\n--- Iteration {iteration} ---")
                print(f"Evaluating removal of {len(selected_features)} features...")
            
            # Try removing each feature
            for feature in selected_features:
                candidate_features = [f for f in selected_features if f != feature]
                score = self._evaluate_features(X_train, y_train, X_val, y_val, candidate_features)
                
                if score > best_iter_score:
                    best_iter_score = score
                    worst_feature = feature
            
            # Check if removal improves or maintains performance
            improvement = best_iter_score - best_score
            
            # Stop if removing features hurts performance significantly
            if improvement < -abs(min_improvement):
                if verbose:
                    print(f"\n✓ Stopping: Removing features degrades performance by {abs(improvement):.6f}")
                break
            
            # Remove worst feature
            selected_features.remove(worst_feature)
            best_score = best_iter_score
            scores_history.append({
                'n_features': len(selected_features),
                'feature_removed': worst_feature,
                'score': best_score
            })
            
            if verbose:
                print(f"✓ Removed feature {worst_feature} | "
                      f"{self.scoring.upper()}: {best_score:.6f} | "
                      f"Change: {improvement:+.6f} | "
                      f"Remaining: {len(selected_features)}")
        
        print("\n" + "=" * 70)
        print(f"BACKWARD ELIMINATION COMPLETE")
        print(f"Selected {len(selected_features)} features")
        print(f"Final {self.scoring}: {best_score:.6f}")
        print("=" * 70)
        
        return {
            'selected_features': selected_features,
            'scores_history': scores_history,
            'final_score': best_score,
            'n_features': len(selected_features)
        }

# %%
df = pd.read_csv('./train1.csv')
X = df.drop(['target','id'], axis=1)
y = df['target']

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=29173, stratify=y)

# %%
categorical_cols = [col for col in X_train.columns if col.endswith('_cat')]
X_train[categorical_cols] = X_train[categorical_cols].astype('category')
X_val[categorical_cols] = X_val[categorical_cols].astype('category')
binary_cols = [col for col in X_train.columns if col.endswith('_bin')]
X_train[binary_cols] = X_train[binary_cols].astype(bool)
X_val[binary_cols] = X_val[binary_cols].astype(bool)

# %%
def class_based_imputer(X, y, categorical_columns=None):
    """
    Class-based imputation for categorical columns using mode values per class.
    """
    X_imputed = X.copy()
    if categorical_columns is None:
        categorical_columns = X.columns.tolist()

    print("="*60)
    print("CLASS-BASED IMPUTATION STARTED")
    print("="*60)
    
    for col in categorical_columns:
        if col not in X_imputed.columns:
            continue

        if X_imputed[col].isnull().sum() == 0:
            continue

        for class_val in [0, 1]:
            class_mask = (y == class_val)
            missing_mask = X_imputed[col].isnull()
            impute_mask = class_mask & missing_mask

            if impute_mask.sum() > 0:
                class_values = X_imputed.loc[class_mask & ~missing_mask, col]
                if len(class_values) > 0:
                    fill_value = class_values.mode()[0]
                else:
                    fill_value = 'Missing'
                X_imputed.loc[impute_mask, col] = fill_value

    print("="*60)
    print("IMPUTATION COMPLETED")
    print("="*60)
    return X_imputed

# %%
print(f"Dataset shape: {X_train.shape}")
class_dist = y_train.value_counts(normalize=True) * 100
print(f"Class 0: {class_dist[0]:.2f}% | Class 1: {class_dist[1]:.2f}%")

print("Missing values per column:")
print(X_train.isnull().sum())

print("="*80)
print("APPLYING CLASS-BASED IMPUTATION")
print("="*80)

X_train = class_based_imputer(X_train, y_train, categorical_cols)
print(f"Dataset shape: {X_val.shape}")
class_dist = y_val.value_counts(normalize=True) * 100
print(f"Class 0: {class_dist[0]:.2f}% | Class 1: {class_dist[1]:.2f}%")

print("Missing values per column:")
print(X_train.isnull().sum())

print("="*80)
print("APPLYING CLASS-BASED IMPUTATION")
print("="*80)

X_val = class_based_imputer(X_val, y_val, categorical_cols)
# Out:
# Dataset shape: (207346, 65)
# Class 0: 94.87% | Class 1: 5.13%
# Missing values per column:
# ps_ind_02_cat       91
# ps_ind_04_cat       33
# ps_ind_05_cat     2030
# ps_car_01_cat       42
# ps_car_02_cat        3
#                  ...
# feature4         37556
# feature5             0
# feature6             0
# feature7             0
# feature8             0
# Length: 65, dtype: int64
# ================================================================================
# APPLYING CLASS-BASED IMPUTATION
# ================================================================================
# ============================================================
# CLASS-BASED IMPUTATION STARTED
# ============================================================
# ============================================================
# IMPUTATION COMPLETED
# ============================================================
# Dataset shape: (88863, 65)
# Class 0: 94.87% | Class 1: 5.13%
# Missing values per column:
# ps_ind_02_cat        0
# ps_ind_04_cat        0
# ps_ind_05_cat        0
# ps_car_01_cat        0
# ps_car_02_cat        0
#                  ...
# feature4         37556
# feature5             0
# feature6             0
# feature7             0
# feature8             0
# Length: 65, dtype: int64
# ================================================================================
# APPLYING CLASS-BASED IMPUTATION
# ================================================================================
# ============================================================
# CLASS-BASED IMPUTATION STARTED
# ============================================================
# ============================================================
# IMPUTATION COMPLETED
# ============================================================

# %%
def class_based_num_imputer(X, y, num_cols=None):
    """
    Perform class-based imputation for numerical columns.
    Each class's missing values are filled using that class's mean.
    """
    X_imputed = X.copy()

    # Identify columns
    categorical_cols = [col for col in X.columns if col.endswith('_cat')]
    binary_cols = [col for col in X.columns if col.endswith('_bin')]

    if num_cols is None:
        num_cols = [col for col in X.columns if not (col.endswith('_cat') or col.endswith('_bin'))]

    # Impute numerical columns class-wise (using mean)
    for col in num_cols:
        if X_imputed[col].isnull().sum() == 0:
            continue

        for class_val in [0, 1]:
            class_mask = (y == class_val)
            missing_mask = X_imputed[col].isnull()
            impute_mask = class_mask & missing_mask

            if impute_mask.sum() > 0:
                class_values = X_imputed.loc[class_mask & ~missing_mask, col]
                if len(class_values) > 0:
                    fill_value = class_values.mean()
                else:
                    fill_value = X_imputed[col].mean()  # fallback global mean
                X_imputed.loc[impute_mask, col] = fill_value

    print("="*60)
    print("IMPUTATION COMPLETED")
    print("="*60)
    return X_imputed

# %%
num_cols = [col for col in X_train.columns if not col.endswith(('_cat', '_bin'))]
X_train =  class_based_num_imputer(X_train,y_train,num_cols)
X_val =  class_based_num_imputer(X_val,y_val,num_cols)
# Out:
# ============================================================
# IMPUTATION COMPLETED
# ============================================================
# ============================================================
# IMPUTATION COMPLETED
# ============================================================

# %%
# Your Decision Tree
dt = DecisionTreeClassifier(
    class_weight=None, 
    criterion='gini', 
    max_depth=5, 
    min_samples_leaf=5, 
    min_samples_split=2,
    random_state=29173
)
roc_auc

# Run Feature Selection
selector = FeatureSelector(estimator=dt, scoring='', task='classification')

forward_results = selector.forward_selection(
    X_train.values, y_train,
    X_val.values, y_val,
    max_features=35
)

backward_results = selector.backward_elimination(
    X_train.values, y_train,
    X_val.values, y_val,
    min_features=35
)
# Out:
# ======================================================================
# FORWARD SELECTION
# ======================================================================
# Total available features: 65
# Maximum features to select: 35
# Scoring metric: accuracy
# ======================================================================
#
# --- Iteration 1 ---
# Evaluating 65 remaining features...
# ✓ Added feature 0 | ACCURACY: 0.948730 | Improvement: +inf | Total features: 1
#
# --- Iteration 2 ---
# Evaluating 64 remaining features...
#
# ✓ Stopping: Improvement 0.000000 < 0.0001
#
# ======================================================================
# FORWARD SELECTION COMPLETE
# Selected 1 features
# Final accuracy: 0.948730
# ======================================================================
#
# ======================================================================
# BACKWARD ELIMINATION
# ======================================================================
# Starting with all 65 features
# Minimum features to keep: 35
# Initial accuracy: 0.948730
# ======================================================================
#
# --- Iteration 1 ---
# Evaluating removal of 65 features...
# ✓ Removed feature 0 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 64
#
# --- Iteration 2 ---
# Evaluating removal of 64 features...
# ✓ Removed feature 1 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 63
#
# --- Iteration 3 ---
# Evaluating removal of 63 features...
# ✓ Removed feature 2 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 62
#
# --- Iteration 4 ---
# Evaluating removal of 62 features...
# ✓ Removed feature 3 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 61
#
# --- Iteration 5 ---
# Evaluating removal of 61 features...
# ✓ Removed feature 4 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 60
#
# --- Iteration 6 ---
# Evaluating removal of 60 features...
# ✓ Removed feature 5 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 59
#
# --- Iteration 7 ---
# Evaluating removal of 59 features...
# ✓ Removed feature 6 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 58
#
# --- Iteration 8 ---
# Evaluating removal of 58 features...
# ✓ Removed feature 7 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 57
#
# --- Iteration 9 ---
# Evaluating removal of 57 features...
# ✓ Removed feature 8 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 56
#
# --- Iteration 10 ---
# Evaluating removal of 56 features...
# ✓ Removed feature 9 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 55
#
# --- Iteration 11 ---
# Evaluating removal of 55 features...
# ✓ Removed feature 10 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 54
#
# --- Iteration 12 ---
# Evaluating removal of 54 features...
# ✓ Removed feature 11 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 53
#
# --- Iteration 13 ---
# Evaluating removal of 53 features...
# ✓ Removed feature 12 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 52
#
# --- Iteration 14 ---
# Evaluating removal of 52 features...
# ✓ Removed feature 13 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 51
#
# --- Iteration 15 ---
# Evaluating removal of 51 features...
# ✓ Removed feature 14 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 50
#
# --- Iteration 16 ---
# Evaluating removal of 50 features...
# ✓ Removed feature 15 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 49
#
# --- Iteration 17 ---
# Evaluating removal of 49 features...
# ✓ Removed feature 16 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 48
#
# --- Iteration 18 ---
# Evaluating removal of 48 features...
# ✓ Removed feature 18 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 47
#
# --- Iteration 19 ---
# Evaluating removal of 47 features...
# ✓ Removed feature 19 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 46
#
# --- Iteration 20 ---
# Evaluating removal of 46 features...
# ✓ Removed feature 20 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 45
#
# --- Iteration 21 ---
# Evaluating removal of 45 features...
# ✓ Removed feature 21 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 44
#
# --- Iteration 22 ---
# Evaluating removal of 44 features...
# ✓ Removed feature 22 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 43
#
# --- Iteration 23 ---
# Evaluating removal of 43 features...
# ✓ Removed feature 23 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 42
#
# --- Iteration 24 ---
# Evaluating removal of 42 features...
# ✓ Removed feature 24 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 41
#
# --- Iteration 25 ---
# Evaluating removal of 41 features...
# ✓ Removed feature 25 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 40
#
# --- Iteration 26 ---
# Evaluating removal of 40 features...
# ✓ Removed feature 26 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 39
#
# --- Iteration 27 ---
# Evaluating removal of 39 features...
# ✓ Removed feature 27 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 38
#
# --- Iteration 28 ---
# Evaluating removal of 38 features...
# ✓ Removed feature 17 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 37
#
# --- Iteration 29 ---
# Evaluating removal of 37 features...
# ✓ Removed feature 28 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 36
#
# --- Iteration 30 ---
# Evaluating removal of 36 features...
# ✓ Removed feature 29 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 35
#
# ======================================================================
# BACKWARD ELIMINATION COMPLETE
# Selected 35 features
# Final accuracy: 0.948730
# ======================================================================

# %%
forward_results2 = selector.forward_selection(
    X_train.values, y_train,
    X_val.values, y_val,
    max_features=66
)

backward_results2 = selector.backward_elimination(
    X_train.values, y_train,
    X_val.values, y_val,
    min_features=1
)
# Out:
# ======================================================================
# FORWARD SELECTION
# ======================================================================
# Total available features: 65
# Maximum features to select: 66
# Scoring metric: accuracy
# ======================================================================
#
# --- Iteration 1 ---
# Evaluating 65 remaining features...
# ✓ Added feature 0 | ACCURACY: 0.948730 | Improvement: +inf | Total features: 1
#
# --- Iteration 2 ---
# Evaluating 64 remaining features...
#
# ✓ Stopping: Improvement 0.000000 < 0.0001
#
# ======================================================================
# FORWARD SELECTION COMPLETE
# Selected 1 features
# Final accuracy: 0.948730
# ======================================================================
#
# ======================================================================
# BACKWARD ELIMINATION
# ======================================================================
# Starting with all 65 features
# Minimum features to keep: 1
# Initial accuracy: 0.948730
# ======================================================================
#
# --- Iteration 1 ---
# Evaluating removal of 65 features...
# ✓ Removed feature 0 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 64
#
# --- Iteration 2 ---
# Evaluating removal of 64 features...
# ✓ Removed feature 1 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 63
#
# --- Iteration 3 ---
# Evaluating removal of 63 features...
# ✓ Removed feature 2 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 62
#
# --- Iteration 4 ---
# Evaluating removal of 62 features...
# ✓ Removed feature 3 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 61
#
# --- Iteration 5 ---
# Evaluating removal of 61 features...
# ✓ Removed feature 4 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 60
#
# --- Iteration 6 ---
# Evaluating removal of 60 features...
# ✓ Removed feature 5 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 59
#
# --- Iteration 7 ---
# Evaluating removal of 59 features...
# ✓ Removed feature 6 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 58
#
# --- Iteration 8 ---
# Evaluating removal of 58 features...
# ✓ Removed feature 7 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 57
#
# --- Iteration 9 ---
# Evaluating removal of 57 features...
# ✓ Removed feature 8 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 56
#
# --- Iteration 10 ---
# Evaluating removal of 56 features...
# ✓ Removed feature 9 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 55
#
# --- Iteration 11 ---
# Evaluating removal of 55 features...
# ✓ Removed feature 10 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 54
#
# --- Iteration 12 ---
# Evaluating removal of 54 features...
# ✓ Removed feature 11 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 53
#
# --- Iteration 13 ---
# Evaluating removal of 53 features...
# ✓ Removed feature 12 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 52
#
# --- Iteration 14 ---
# Evaluating removal of 52 features...
# ✓ Removed feature 13 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 51
#
# --- Iteration 15 ---
# Evaluating removal of 51 features...
# ✓ Removed feature 14 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 50
#
# --- Iteration 16 ---
# Evaluating removal of 50 features...
# ✓ Removed feature 15 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 49
#
# --- Iteration 17 ---
# Evaluating removal of 49 features...
# ✓ Removed feature 16 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 48
#
# --- Iteration 18 ---
# Evaluating removal of 48 features...
# ✓ Removed feature 18 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 47
#
# --- Iteration 19 ---
# Evaluating removal of 47 features...
# ✓ Removed feature 19 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 46
#
# --- Iteration 20 ---
# Evaluating removal of 46 features...
# ✓ Removed feature 20 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 45
#
# --- Iteration 21 ---
# Evaluating removal of 45 features...
# ✓ Removed feature 21 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 44
#
# --- Iteration 22 ---
# Evaluating removal of 44 features...
# ✓ Removed feature 22 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 43
#
# --- Iteration 23 ---
# Evaluating removal of 43 features...
# ✓ Removed feature 23 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 42
#
# --- Iteration 24 ---
# Evaluating removal of 42 features...
# ✓ Removed feature 24 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 41
#
# --- Iteration 25 ---
# Evaluating removal of 41 features...
# ✓ Removed feature 25 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 40
#
# --- Iteration 26 ---
# Evaluating removal of 40 features...
# ✓ Removed feature 26 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 39
#
# --- Iteration 27 ---
# Evaluating removal of 39 features...
# ✓ Removed feature 27 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 38
#
# --- Iteration 28 ---
# Evaluating removal of 38 features...
# ✓ Removed feature 17 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 37
#
# --- Iteration 29 ---
# Evaluating removal of 37 features...
# ✓ Removed feature 28 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 36
#
# --- Iteration 30 ---
# Evaluating removal of 36 features...
# ✓ Removed feature 29 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 35
#
# --- Iteration 31 ---
# Evaluating removal of 35 features...
# ✓ Removed feature 30 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 34
#
# --- Iteration 32 ---
# Evaluating removal of 34 features...
# ✓ Removed feature 31 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 33
#
# --- Iteration 33 ---
# Evaluating removal of 33 features...
# ✓ Removed feature 32 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 32
#
# --- Iteration 34 ---
# Evaluating removal of 32 features...
# ✓ Removed feature 33 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 31
#
# --- Iteration 35 ---
# Evaluating removal of 31 features...
# ✓ Removed feature 34 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 30
#
# --- Iteration 36 ---
# Evaluating removal of 30 features...
# ✓ Removed feature 36 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 29
#
# --- Iteration 37 ---
# Evaluating removal of 29 features...
# ✓ Removed feature 37 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 28
#
# --- Iteration 38 ---
# Evaluating removal of 28 features...
# ✓ Removed feature 38 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 27
#
# --- Iteration 39 ---
# Evaluating removal of 27 features...
# ✓ Removed feature 39 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 26
#
# --- Iteration 40 ---
# Evaluating removal of 26 features...
# ✓ Removed feature 40 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 25
#
# --- Iteration 41 ---
# Evaluating removal of 25 features...
# ✓ Removed feature 41 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 24
#
# --- Iteration 42 ---
# Evaluating removal of 24 features...
# ✓ Removed feature 42 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 23
#
# --- Iteration 43 ---
# Evaluating removal of 23 features...
# ✓ Removed feature 43 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 22
#
# --- Iteration 44 ---
# Evaluating removal of 22 features...
# ✓ Removed feature 44 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 21
#
# --- Iteration 45 ---
# Evaluating removal of 21 features...
# ✓ Removed feature 45 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 20
#
# --- Iteration 46 ---
# Evaluating removal of 20 features...
# ✓ Removed feature 46 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 19
#
# --- Iteration 47 ---
# Evaluating removal of 19 features...
# ✓ Removed feature 47 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 18
#
# --- Iteration 48 ---
# Evaluating removal of 18 features...
# ✓ Removed feature 48 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 17
#
# --- Iteration 49 ---
# Evaluating removal of 17 features...
# ✓ Removed feature 49 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 16
#
# --- Iteration 50 ---
# Evaluating removal of 16 features...
# ✓ Removed feature 50 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 15
#
# --- Iteration 51 ---
# Evaluating removal of 15 features...
# ✓ Removed feature 51 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 14
#
# --- Iteration 52 ---
# Evaluating removal of 14 features...
# ✓ Removed feature 52 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 13
#
# --- Iteration 53 ---
# Evaluating removal of 13 features...
# ✓ Removed feature 53 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 12
#
# --- Iteration 54 ---
# Evaluating removal of 12 features...
# ✓ Removed feature 54 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 11
#
# --- Iteration 55 ---
# Evaluating removal of 11 features...
# ✓ Removed feature 55 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 10
#
# --- Iteration 56 ---
# Evaluating removal of 10 features...
# ✓ Removed feature 56 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 9
#
# --- Iteration 57 ---
# Evaluating removal of 9 features...
# ✓ Removed feature 57 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 8
#
# --- Iteration 58 ---
# Evaluating removal of 8 features...
# ✓ Removed feature 58 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 7
#
# --- Iteration 59 ---
# Evaluating removal of 7 features...
# ✓ Removed feature 59 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 6
#
# --- Iteration 60 ---
# Evaluating removal of 6 features...
# ✓ Removed feature 61 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 5
#
# --- Iteration 61 ---
# Evaluating removal of 5 features...
# ✓ Removed feature 62 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 4
#
# --- Iteration 62 ---
# Evaluating removal of 4 features...
# ✓ Removed feature 60 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 3
#
# --- Iteration 63 ---
# Evaluating removal of 3 features...
# ✓ Removed feature 35 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 2
#
# --- Iteration 64 ---
# Evaluating removal of 2 features...
# ✓ Removed feature 63 | ACCURACY: 0.948730 | Change: +0.000000 | Remaining: 1
#
# ======================================================================
# BACKWARD ELIMINATION COMPLETE
# Selected 1 features
# Final accuracy: 0.948730
# ======================================================================

# %%
# Your Decision Tree
dt = DecisionTreeClassifier(
    class_weight=None, 
    criterion='gini', 
    max_depth=5, 
    min_samples_leaf=5, 
    min_samples_split=2,
    random_state=29173
)


# Run Feature Selection
selector = FeatureSelector(estimator=dt, scoring='roc_auc', task='classification')

forward_results3 = selector.forward_selection(
    X_train.values, y_train,
    X_val.values, y_val,
    max_features=66
)

backward_results3 = selector.backward_elimination(
    X_train.values, y_train,
    X_val.values, y_val,
    min_features=1
)
# Out:
# ======================================================================
# FORWARD SELECTION
# ======================================================================
# Total available features: 65
# Maximum features to select: 66
# Scoring metric: roc_auc
# ======================================================================
#
# --- Iteration 1 ---
# Evaluating 65 remaining features...
# ✓ Added feature 34 | ROC_AUC: 0.579119 | Improvement: +inf | Total features: 1
#
# --- Iteration 2 ---
# Evaluating 64 remaining features...
# ✓ Added feature 27 | ROC_AUC: 0.593442 | Improvement: +0.014324 | Total features: 2
#
# --- Iteration 3 ---
# Evaluating 63 remaining features...
# ✓ Added feature 60 | ROC_AUC: 0.617423 | Improvement: +0.023981 | Total features: 3
#
# --- Iteration 4 ---
# Evaluating 62 remaining features...
# ✓ Added feature 25 | ROC_AUC: 0.623358 | Improvement: +0.005934 | Total features: 4
#
# --- Iteration 5 ---
# Evaluating 61 remaining features...
# ✓ Added feature 6 | ROC_AUC: 0.627596 | Improvement: +0.004239 | Total features: 5
#
# --- Iteration 6 ---
# Evaluating 60 remaining features...
# ✓ Added feature 30 | ROC_AUC: 0.629835 | Improvement: +0.002239 | Total features: 6
#
# --- Iteration 7 ---
# Evaluating 59 remaining features...
# ✓ Added feature 56 | ROC_AUC: 0.630645 | Improvement: +0.000810 | Total features: 7
#
# --- Iteration 8 ---
# Evaluating 58 remaining features...
#
# ✓ Stopping: Improvement 0.000000 < 0.0001
#
# ======================================================================
# FORWARD SELECTION COMPLETE
# Selected 7 features
# Final roc_auc: 0.630645
# ======================================================================
#
# ======================================================================
# BACKWARD ELIMINATION
# ======================================================================
# Starting with all 65 features
# Minimum features to keep: 1
# Initial roc_auc: 0.604132
# ======================================================================
#
# --- Iteration 1 ---
# Evaluating removal of 65 features...
# ✓ Removed feature 34 | ROC_AUC: 0.623725 | Change: +0.019593 | Remaining: 64
#
# --- Iteration 2 ---
# Evaluating removal of 64 features...
# ✓ Removed feature 60 | ROC_AUC: 0.635969 | Change: +0.012244 | Remaining: 63
#
# --- Iteration 3 ---
# Evaluating removal of 63 features...
# ✓ Removed feature 17 | ROC_AUC: 0.642628 | Change: +0.006659 | Remaining: 62
#
# --- Iteration 4 ---
# Evaluating removal of 62 features...
# ✓ Removed feature 0 | ROC_AUC: 0.642640 | Change: +0.000012 | Remaining: 61
#
# --- Iteration 5 ---
# Evaluating removal of 61 features...
# ✓ Removed feature 20 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 60
#
# --- Iteration 6 ---
# Evaluating removal of 60 features...
# ✓ Removed feature 23 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 59
#
# --- Iteration 7 ---
# Evaluating removal of 59 features...
# ✓ Removed feature 1 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 58
#
# --- Iteration 8 ---
# Evaluating removal of 58 features...
# ✓ Removed feature 3 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 57
#
# --- Iteration 9 ---
# Evaluating removal of 57 features...
# ✓ Removed feature 46 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 56
#
# --- Iteration 10 ---
# Evaluating removal of 56 features...
# ✓ Removed feature 4 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 55
#
# --- Iteration 11 ---
# Evaluating removal of 55 features...
# ✓ Removed feature 5 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 54
#
# --- Iteration 12 ---
# Evaluating removal of 54 features...
# ✓ Removed feature 25 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 53
#
# --- Iteration 13 ---
# Evaluating removal of 53 features...
# ✓ Removed feature 7 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 52
#
# --- Iteration 14 ---
# Evaluating removal of 52 features...
# ✓ Removed feature 8 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 51
#
# --- Iteration 15 ---
# Evaluating removal of 51 features...
# ✓ Removed feature 9 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 50
#
# --- Iteration 16 ---
# Evaluating removal of 50 features...
# ✓ Removed feature 10 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 49
#
# --- Iteration 17 ---
# Evaluating removal of 49 features...
# ✓ Removed feature 11 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 48
#
# --- Iteration 18 ---
# Evaluating removal of 48 features...
# ✓ Removed feature 12 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 47
#
# --- Iteration 19 ---
# Evaluating removal of 47 features...
# ✓ Removed feature 13 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 46
#
# --- Iteration 20 ---
# Evaluating removal of 46 features...
# ✓ Removed feature 14 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 45
#
# --- Iteration 21 ---
# Evaluating removal of 45 features...
# ✓ Removed feature 16 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 44
#
# --- Iteration 22 ---
# Evaluating removal of 44 features...
# ✓ Removed feature 18 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 43
#
# --- Iteration 23 ---
# Evaluating removal of 43 features...
# ✓ Removed feature 19 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 42
#
# --- Iteration 24 ---
# Evaluating removal of 42 features...
# ✓ Removed feature 21 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 41
#
# --- Iteration 25 ---
# Evaluating removal of 41 features...
# ✓ Removed feature 22 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 40
#
# --- Iteration 26 ---
# Evaluating removal of 40 features...
# ✓ Removed feature 24 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 39
#
# --- Iteration 27 ---
# Evaluating removal of 39 features...
# ✓ Removed feature 26 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 38
#
# --- Iteration 28 ---
# Evaluating removal of 38 features...
# ✓ Removed feature 28 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 37
#
# --- Iteration 29 ---
# Evaluating removal of 37 features...
# ✓ Removed feature 29 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 36
#
# --- Iteration 30 ---
# Evaluating removal of 36 features...
# ✓ Removed feature 30 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 35
#
# --- Iteration 31 ---
# Evaluating removal of 35 features...
# ✓ Removed feature 32 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 34
#
# --- Iteration 32 ---
# Evaluating removal of 34 features...
# ✓ Removed feature 33 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 33
#
# --- Iteration 33 ---
# Evaluating removal of 33 features...
# ✓ Removed feature 37 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 32
#
# --- Iteration 34 ---
# Evaluating removal of 32 features...
# ✓ Removed feature 38 | ROC_AUC: 0.642640 | Change: +0.000000 | Remaining: 31
#
# --- Iteration 35 ---
# Evaluating removal of 31 features...
# ✓ Removed feature 39 | ROC_AUC: 0.642663 | Change: +0.000023 | Remaining: 30
#
# --- Iteration 36 ---
# Evaluating removal of 30 features...
# ✓ Removed feature 40 | ROC_AUC: 0.642663 | Change: +0.000000 | Remaining: 29
#
# --- Iteration 37 ---
# Evaluating removal of 29 features...
# ✓ Removed feature 41 | ROC_AUC: 0.642663 | Change: +0.000000 | Remaining: 28
#
# --- Iteration 38 ---
# Evaluating removal of 28 features...
# ✓ Removed feature 42 | ROC_AUC: 0.642663 | Change: +0.000000 | Remaining: 27
#
# --- Iteration 39 ---
# Evaluating removal of 27 features...
# ✓ Removed feature 43 | ROC_AUC: 0.642663 | Change: +0.000000 | Remaining: 26
#
# --- Iteration 40 ---
# Evaluating removal of 26 features...
# ✓ Removed feature 44 | ROC_AUC: 0.642663 | Change: +0.000000 | Remaining: 25
#
# --- Iteration 41 ---
# Evaluating removal of 25 features...
# ✓ Removed feature 45 | ROC_AUC: 0.642663 | Change: +0.000000 | Remaining: 24
#
# --- Iteration 42 ---
# Evaluating removal of 24 features...
# ✓ Removed feature 47 | ROC_AUC: 0.642663 | Change: +0.000000 | Remaining: 23
#
# --- Iteration 43 ---
# Evaluating removal of 23 features...
# ✓ Removed feature 48 | ROC_AUC: 0.642663 | Change: +0.000000 | Remaining: 22
#
# --- Iteration 44 ---
# Evaluating removal of 22 features...
# ✓ Removed feature 49 | ROC_AUC: 0.642663 | Change: +0.000000 | Remaining: 21
#
# --- Iteration 45 ---
# Evaluating removal of 21 features...
# ✓ Removed feature 50 | ROC_AUC: 0.642663 | Change: +0.000000 | Remaining: 20
#
# --- Iteration 46 ---
# Evaluating removal of 20 features...
# ✓ Removed feature 51 | ROC_AUC: 0.642663 | Change: +0.000000 | Remaining: 19
#
# --- Iteration 47 ---
# Evaluating removal of 19 features...
# ✓ Removed feature 52 | ROC_AUC: 0.642663 | Change: +0.000000 | Remaining: 18
#
# --- Iteration 48 ---
# Evaluating removal of 18 features...
# ✓ Removed feature 53 | ROC_AUC: 0.642663 | Change: +0.000000 | Remaining: 17
#
# --- Iteration 49 ---
# Evaluating removal of 17 features...
# ✓ Removed feature 54 | ROC_AUC: 0.642663 | Change: +0.000000 | Remaining: 16
#
# --- Iteration 50 ---
# Evaluating removal of 16 features...
# ✓ Removed feature 55 | ROC_AUC: 0.642663 | Change: +0.000000 | Remaining: 15
#
# --- Iteration 51 ---
# Evaluating removal of 15 features...
# ✓ Removed feature 56 | ROC_AUC: 0.642663 | Change: +0.000000 | Remaining: 14
#
# --- Iteration 52 ---
# Evaluating removal of 14 features...
# ✓ Removed feature 57 | ROC_AUC: 0.642663 | Change: +0.000000 | Remaining: 13
#
# --- Iteration 53 ---
# Evaluating removal of 13 features...
# ✓ Removed feature 58 | ROC_AUC: 0.642663 | Change: +0.000000 | Remaining: 12
#
# --- Iteration 54 ---
# Evaluating removal of 12 features...
# ✓ Removed feature 15 | ROC_AUC: 0.642693 | Change: +0.000031 | Remaining: 11
#
# --- Iteration 55 ---
# Evaluating removal of 11 features...
# ✓ Removed feature 59 | ROC_AUC: 0.642693 | Change: +0.000000 | Remaining: 10
#
# --- Iteration 56 ---
# Evaluating removal of 10 features...
# ✓ Removed feature 61 | ROC_AUC: 0.642693 | Change: +0.000000 | Remaining: 9
#
# --- Iteration 57 ---
# Evaluating removal of 9 features...
# ✓ Removed feature 62 | ROC_AUC: 0.642693 | Change: +0.000000 | Remaining: 8
#
# --- Iteration 58 ---
# Evaluating removal of 8 features...
# ✓ Removed feature 64 | ROC_AUC: 0.642693 | Change: +0.000000 | Remaining: 7
#
# --- Iteration 59 ---
# Evaluating removal of 7 features...
# ✓ Removed feature 63 | ROC_AUC: 0.642677 | Change: -0.000017 | Remaining: 6
#
# --- Iteration 60 ---
# Evaluating removal of 6 features...
#
# ✓ Stopping: Removing features degrades performance by 0.001454
#
# ======================================================================
# BACKWARD ELIMINATION COMPLETE
# Selected 6 features
# Final roc_auc: 0.642677
# ======================================================================

# %%
forward_selected_idx = forward_results3['selected_features']
backward_selected_idx = backward_results3['selected_features']

# %%
forward_selected_idx
# Out:
# [34, 27, 60, 25, 6, 30, 56]

# %%
backward_selected_idx
# Out:
# [2, 6, 27, 31, 35, 36]

# %%
forward_selected_features = X_train.columns[forward_selected_idx]
backward_selected_features = X_train.columns[backward_selected_idx]

# %%
forward_selected_features
# Out:
# Index(['ps_car_13', 'ps_ind_17_bin', 'feature4', 'ps_ind_15', 'ps_car_04_cat',
#        'ps_reg_02', 'ps_calc_20_bin'],
#       dtype='object')

# %%
backward_selected_features
# Out:
# Index(['ps_ind_05_cat', 'ps_car_04_cat', 'ps_ind_17_bin', 'ps_reg_03',
#        'ps_car_14', 'ps_car_15'],
#       dtype='object')

# %%
# Your Decision Tree
dt = DecisionTreeClassifier(random_state=29173)


# Run Feature Selection
selector = FeatureSelector(estimator=dt, scoring='roc_auc', task='classification')

forward_results3 = selector.forward_selection(
    X_train.values, y_train,
    X_val.values, y_val,
    max_features=66
)

backward_results3 = selector.backward_elimination(
    X_train.values, y_train,
    X_val.values, y_val,
    min_features=1
)
# Out:
# ======================================================================
# FORWARD SELECTION
# ======================================================================
# Total available features: 65
# Maximum features to select: 66
# Scoring metric: roc_auc
# ======================================================================
#
# --- Iteration 1 ---
# Evaluating 65 remaining features...
# ✓ Added feature 13 | ROC_AUC: 0.569937 | Improvement: +inf | Total features: 1
#
# --- Iteration 2 ---
# Evaluating 64 remaining features...
# ✓ Added feature 27 | ROC_AUC: 0.582728 | Improvement: +0.012791 | Total features: 2
#
# --- Iteration 3 ---
# Evaluating 63 remaining features...
# ✓ Added feature 6 | ROC_AUC: 0.589139 | Improvement: +0.006411 | Total features: 3
#
# --- Iteration 4 ---
# Evaluating 62 remaining features...
#
# ✓ Stopping: Improvement 0.000065 < 0.0001
#
# ======================================================================
# FORWARD SELECTION COMPLETE
# Selected 3 features
# Final roc_auc: 0.589139
# ======================================================================
#
# ======================================================================
# BACKWARD ELIMINATION
# ======================================================================
# Starting with all 65 features
# Minimum features to keep: 1
# Initial roc_auc: 0.501034
# ======================================================================
#
# --- Iteration 1 ---
# Evaluating removal of 65 features...
# ✓ Removed feature 2 | ROC_AUC: 0.508825 | Change: +0.007791 | Remaining: 64
#
# --- Iteration 2 ---
# Evaluating removal of 64 features...
# ✓ Removed feature 63 | ROC_AUC: 0.511951 | Change: +0.003126 | Remaining: 63
#
# --- Iteration 3 ---
# Evaluating removal of 63 features...
# ✓ Removed feature 48 | ROC_AUC: 0.511854 | Change: -0.000098 | Remaining: 62
#
# --- Iteration 4 ---
# Evaluating removal of 62 features...
# ✓ Removed feature 52 | ROC_AUC: 0.511913 | Change: +0.000059 | Remaining: 61
#
# --- Iteration 5 ---
# Evaluating removal of 61 features...
# ✓ Removed feature 29 | ROC_AUC: 0.512440 | Change: +0.000527 | Remaining: 60
#
# --- Iteration 6 ---
# Evaluating removal of 60 features...
# ✓ Removed feature 7 | ROC_AUC: 0.514380 | Change: +0.001940 | Remaining: 59
#
# --- Iteration 7 ---
# Evaluating removal of 59 features...
#
# ✓ Stopping: Removing features degrades performance by 0.000507
#
# ======================================================================
# BACKWARD ELIMINATION COMPLETE
# Selected 59 features
# Final roc_auc: 0.514380
# ======================================================================
